# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
#Read the data file
f = h5py.File('data.h5','r')

#Get the train and test sets information
for name in f:
    print('{0} : {1}'.format(name, f[name].shape))
# Out:
# X : (439452, 400)
# testX : (146484, 400)
# test_files : (146484,)
# testy : (146484,)
# train_files : (439452,)
# y : (439452,)

# %%
#The images are of shape 20*20
#Each row in X and testX represents an image
#Reshape both arrays, so they are 3D and represents multiple images in 2D format
xTrain = np.reshape(f['X'], (-1,20,20))
xTest = np.reshape(f['testX'], (-1,20,20))

yTrain = f['y']
yTest = f['testy']

# %%
#Display some random images and their classification

fig = plt.figure(figsize=(8, 8))
columns = 4
rows = 5
for i in range(1, columns*rows +1):
    index = np.random.randint(0,len(xTrain))
    fig.add_subplot(rows, columns, i)
    plt.imshow(xTrain[index], cmap='gray')
    plt.xticks([])
    plt.yticks([])
    plt.xlabel(yTrain[index])
plt.show()
